# %%
### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()  # Load environment variables from .env file

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")  # Get the OpenAI API key from environment variables

if OPENAI_API_KEY is None:
    raise BaseExceptionGroup("API KEY is missing.") #ValueError can also be used
else:
    print(OPENAI_API_KEY[:8])
    
    # Set the API key for OpenAI
# Out:
# sk-proj-

# %%
client= OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
              {"role": "user", "content": "what is an okapi"} ]
    )

answer=response.choices[0].message.content
print(answer)
# Out:
# An **okapi** is a mammal native to the dense rainforests of the Democratic Republic of Congo in Central Africa. Despite its zebra-like stripes on its legs, the okapi is closely related to the giraffe and is sometimes called the "forest giraffe."
#
# ### Key facts about the okapi:
# - **Scientific name:** *Okapia johnstoni*
# - **Appearance:** It has a body shape similar to a giraffe but with a much shorter neck, reddish-brown coat, and distinctive horizontal white stripes on its legs and hindquarters, which help it blend into the forest.
# - **Size:** About 1.5 to 2 meters (4.9 to 6.6 feet) tall at the shoulder.
# - **Diet:** Herbivore, feeding mainly on leaves, buds, grasses, fruits, and fungi.
# - **Behavior:** Solitary and shy, mostly active during the day.
# - **Discovery:** Known to local people for centuries but introduced to western science only in the early 20th century.
#
# The okapi is considered a unique and elusive animal, and it is classified as **Endangered** due to habitat loss and hunting pressures.
